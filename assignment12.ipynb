# %%
import pandas as pd
import numpy as np
df=pd.read_csv('/content/adult_with_headers.csv')

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country  income
# 0          2174             0              40   United-States   <=50K
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education_num   32561 non-null  int64
#  5   marital_status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital_gain    32561 non-null  int64
#  11  capital_loss    32561 non-null  int64
#  12  hours_per_week  32561 non-null  int64
#  13  native_country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.describe()
# Out:
#                 age        fnlwgt  education_num  capital_gain  capital_loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours_per_week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# income            0
# dtype: int64

# %% [markdown]
# Here we couldnot find any null values

# %%
numeric_columns=df.select_dtypes(include=['int64','float64']).columns

# %%
import matplotlib.pyplot as plt
import seaborn as sns
for col in numeric_columns:
  plt.figure(figsize=(10,6))
  sns.boxplot(df[col])
  plt.title(f'Distribution of {col}')
  plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
for col in numeric_columns:
  plt.figure(figsize=(10,6))
  sns.distplot(df[col])
  plt.title(f'Distribution of {col}')
  plt.show()
# Out:
# <ipython-input-10-33baa8ab116e>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col])
# <ipython-input-10-33baa8ab116e>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col])
# <ipython-input-10-33baa8ab116e>:5: UserWarning:
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
numeric_columns=df.select_dtypes(include=['int64','float64']).columns
sacled_data=scaler.fit_transform(df[numeric_columns])
scaled_data_df=pd.DataFrame(sacled_data,columns=[f"{col}_standardized" for col in numeric_columns])
scaled_data_df.head()
# Out:
#    age_standardized  fnlwgt_standardized  education_num_standardized  \
# 0          0.030671            -1.063611                    1.134739
# 1          0.837109            -1.008707                    1.134739
# 2         -0.042642             0.245079                   -0.420060
# 3          1.057047             0.425801                   -1.197459
# 4         -0.775768             1.408176                    1.134739
#
#    capital_gain_standardized  capital_loss_standardized  \
# 0                   0.148453                   -0.21666
# 1                  -0.145920                   -0.21666
# 2                  -0.145920                   -0.21666
# 3                  -0.145920                   -0.21666
# 4                  -0.145920                   -0.21666
#
#    hours_per_week_standardized
# 0                    -0.035429
# 1                    -2.222153
# 2                    -0.035429
# 3                    -0.035429
# 4                    -0.035429

# %%
from sklearn.preprocessing import  MinMaxScaler
min_max_scaler=MinMaxScaler()
numeric_columns=df.select_dtypes(include=['int64','float64']).columns
min_max_data=min_max_scaler.fit_transform(df[numeric_columns])
min_max_data_df=pd.DataFrame(min_max_data,columns=[f"{col}_standardized" for col in numeric_columns])
min_max_data_df.head()
# Out:
#    age_standardized  fnlwgt_standardized  education_num_standardized  \
# 0          0.301370             0.044302                    0.800000
# 1          0.452055             0.048238                    0.800000
# 2          0.287671             0.138113                    0.533333
# 3          0.493151             0.151068                    0.400000
# 4          0.150685             0.221488                    0.800000
#
#    capital_gain_standardized  capital_loss_standardized  \
# 0                    0.02174                        0.0
# 1                    0.00000                        0.0
# 2                    0.00000                        0.0
# 3                    0.00000                        0.0
# 4                    0.00000                        0.0
#
#    hours_per_week_standardized
# 0                     0.397959
# 1                     0.122449
# 2                     0.397959
# 3                     0.397959
# 4                     0.397959

# %% [markdown]
# Converting categorical to numerical

# %%
categorical_columns=df.select_dtypes(include=['object']).columns
print(  categorical_columns)
# Out:
# Index(['workclass', 'education', 'marital_status', 'occupation',
#        'relationship', 'race', 'sex', 'native_country', 'income'],
#       dtype='object')

# %% [markdown]
# Applying one hot encoding for values less than 5

# %%
columns_to_encode = [col for col in categorical_columns if df[col].nunique() < 5]
print("\nColumns to Encode:", columns_to_encode)

df_encoded = pd.get_dummies(df, columns=columns_to_encode)
# Out:
# Columns to Encode: ['sex', 'income']

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
label_eco=[col for col in categorical_columns if df[col].nunique()>=5]
print("\nLabel Encoded Columns:", label_eco)
for col in label_eco:
  df[col]=label_encoder.fit_transform(df[col])
print("\nLabel Encoded DataFrame:\n", df)
# Out:
# Label Encoded Columns: ['workclass', 'education', 'marital_status', 'occupation', 'relationship', 'race', 'native_country']
#
# Label Encoded DataFrame:
#         age  workclass  fnlwgt  education  education_num  marital_status  \
# 0       39          7   77516          9             13               4
# 1       50          6   83311          9             13               2
# 2       38          4  215646         11              9               0
# 3       53          4  234721          1              7               2
# 4       28          4  338409          9             13               2
# ...    ...        ...     ...        ...            ...             ...
# 32556   27          4  257302          7             12               2
# 32557   40          4  154374         11              9               2
# 32558   58          4  151910         11              9               6
# 32559   22          4  201490         11              9               4
# ...

# %%
df['education'].value_counts()
# Out:
# 11    10501
# 15     7291
# 9      5355
# 12     1723
# 8      1382
# 1      1175
# 7      1067
# 0       933
# 5       646
# 14      576
# 6       514
# 2       433
# 10      413
# 4       333
# 3       168
# 13       51
# Name: education, dtype: int64

# %%
import pandas as pd

def categorize_age(age):
    if age <= 25:
        return '18-25'
    elif age <= 35:
        return '26-35'
    elif age <= 45:
        return '36-45'
    elif age <= 55:
        return '46-55'
    elif age <= 65:
        return '56-65'
    else:
        return '66+'

df['age_group'] = df['age'].apply(categorize_age)


df['work_experience'] = df['age'] - (df['education_num'] + 6)

print(df.head())
# Out:
#    age  workclass  fnlwgt  education  education_num  marital_status  \
# 0   39          7   77516          9             13               4
# 1   50          6   83311          9             13               2
# 2   38          4  215646         11              9               0
# 3   53          4  234721          1              7               2
# 4   28          4  338409          9             13               2
#
#    occupation  relationship  race      sex  capital_gain  capital_loss  \
# 0           1             1     4     Male          2174             0
# 1           4             0     4     Male             0             0
# 2           6             1     4     Male             0             0
# 3           6             0     2     Male             0             0
# 4          10             5     2   Female             0             0
#
#    hours_per_week  native_country  income age_group  work_experience
# ...

# %% [markdown]
# We added age_group and work_experience columns

# %% [markdown]
# On above graph we plotted we casn say that captial_loss and captial_gain data is skewed data as one is completely lies towards right and one to left , only one has most data points and other side it is nearly to zero.

# %%
df['capital_gain_log'] = np.log1p(df['capital_gain'])


print(df[['capital_gain', 'capital_gain_log']].head())
# Out:
#    capital_gain  capital_gain_log
# 0          2174          7.684784
# 1             0          0.000000
# 2             0          0.000000
# 3             0          0.000000
# 4             0          0.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.histplot(df['capital_gain_log'], bins=20, kde=True)
plt.xlabel('Capital Gain')
plt.title('Distribution of Capital Gain')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.hist(df['capital_gain'],bins=50)
plt.xlabel('Capital Gain')
plt.title('Distribution of Capital Gain')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.hist(df['capital_gain_log'],bins=50)
plt.xlabel('Capital Gain')
plt.title('Distribution of Capital Gain')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ISOLATION Forest

# %%
df.head()
# Out:
#    age  workclass  fnlwgt  education  education_num  marital_status  \
# 0   39          7   77516          9             13               4
# 1   50          6   83311          9             13               2
# 2   38          4  215646         11              9               0
# 3   53          4  234721          1              7               2
# 4   28          4  338409          9             13               2
#
#    occupation  relationship  race      sex  capital_gain  capital_loss  \
# 0           1             1     4     Male          2174             0
# 1           4             0     4     Male             0             0
# 2           6             1     4     Male             0             0
# 3           6             0     2     Male             0             0
# 4          10             5     2   Female             0             0
#
#    hours_per_week  native_country  income age_group  work_experience  \
# ...

# %%
df['sex'].value_counts()
# Out:
#  Male      21790
#  Female    10771
# Name: sex, dtype: int64

# %%
df['sex']=df['sex'].replace(['Male','Female'],[0,1])

# %%
df.head()
# Out:
#    age  workclass  fnlwgt  education  education_num  marital_status  \
# 0   39          7   77516          9             13               4
# 1   50          6   83311          9             13               2
# 2   38          4  215646         11              9               0
# 3   53          4  234721          1              7               2
# 4   28          4  338409          9             13               2
#
#    occupation  relationship  race      sex  capital_gain  capital_loss  \
# 0           1             1     4     Male          2174             0
# 1           4             0     4     Male             0             0
# 2           6             1     4     Male             0             0
# 3           6             0     2     Male             0             0
# 4          10             5     2   Female             0             0
#
#    hours_per_week  native_country  income age_group  work_experience  \
# ...

# %%
new_numeric=df.select_dtypes(include=['int64','float64']).columns

# %%
print(new_numeric)
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'capital_gain',
#        'capital_loss', 'hours_per_week', 'native_country', 'work_experience',
#        'capital_gain_log'],
#       dtype='object')

# %%
from sklearn.ensemble import IsolationForest


iso_forest = IsolationForest(contamination=0.1, random_state=42)


X = df.select_dtypes(include=['int64','float64'])


iso_forest.fit(X)

df['anomaly'] = iso_forest.predict(X)
anomalies = df[df['anomaly'] == -1]
print("Anomalies detected:")
print(anomalies)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# Anomalies detected:
#        age  workclass  fnlwgt  education  education_num  marital_status  \
# 4       28          4  338409          9             13               2
# 8       31          4   45781         12             14               4
# 15      34          4  245487          5              4               2
# 27      54          0  180211         15             10               2
# 52      47          4   51835         14             15               2
# ...    ...        ...     ...        ...            ...             ...
# 32538   38          4  139180          9             13               0
# 32539   71          0  287372         10             16               2
# 32548   65          6   99359         14             15               4
# ...

# %% [markdown]
# 1.   These outliers may cause a biased result
# 2.   Leads to high prediction errors
#
#
#
# 1.   Overfitting
# 2.   Impact the model performance

# %%
pip install pandas ppscore

# %%
import ppscore as pps
pps_matrix = pps.matrix(df)
pps_matrix = pps_matrix.pivot(columns='x', index='y', values='ppscore')

correlation_matrix = df.corr()


plt.figure(figsize=(12, 8))
sns.heatmap(pps_matrix, annot=True, cmap='coolwarm')
plt.title('PPS Matrix')
plt.show()


plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
# Out:
# <ipython-input-30-33586724e067>:6: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()
